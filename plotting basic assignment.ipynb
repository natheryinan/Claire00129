# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df=pd.read_csv('data/AB_NYC_2019.csv')
print(df)

print(type(df))
df1 = df.iloc[:,9]
df2= df.iloc[:,15]
print(df1)
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
print(df2)
# Out:
# 0        365
# 1        355
# 2        365
# 3        194
# 4          0
#         ...
# 48890      9
# 48891     36
# 48892     27
# 48893      2
# 48894     23
# Name: availability_365, Length: 48895, dtype: int64

# %%
print(df1)
# Out:
# 0        149
# 1        225
# 2        150
# 3         89
# 4         80
#         ...
# 48890     70
# 48891     40
# 48892    115
# 48893     55
# 48894     90
# Name: price, Length: 48895, dtype: int64

# %%
plt.boxplot(df1)
plt.show()
plt.hist(df1, color='blue')
plt.show()

# %%
# from the plot above, it shows that the column "price" mean value is close to zero, and most of the prices are below 2000
#from the histogram plot it shows the majority of the prices are below 1000

# %%
plt.plot(df1)
plt.show()

# %%
plt.scatter(x=df1, y=df2)
plt.show()

# %%
#from the plot above, I'm trying to see the relationship between "price" and "availability", but it doesn't show much relation from the plot

# %%
#df.plot(kind='scatter', x=df2,y=df1)
#df.plot(kind='line')
#plt.show()

df.plot(kind='scatter', x="price",y="availability_365")
df["price"].plot(kind='line')
plt.show()

# %%
plt.plot(df1)
plt.scatter(df1, df2)
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(df['price'], color='purple')
plt.ylabel('price')
plt.title('price plot')

plt.subplot(1, 2, 2)
plt.plot(df['availability_365'], color='green')
plt.ylabel('availability_365')
plt.title('availability plot')
plt.show()

# %%
#from the plots above, it shows price values are random distrubited?!
